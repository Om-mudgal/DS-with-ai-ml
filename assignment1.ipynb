# %%
# Q1.

name = "Om Mudgal"
course = "B-tech" 
age = 21
city = "jaipur"

print("name :",name)
print("course :",course)
print("age :",age)
print("city :",city)
# Out:
# name : Om Mudgal
# course : B-tech
# age : 21
# city : jaipur

# %%
# Q2.

name = input("enter the name :")
age =  int(input("enter the age :"))

print("Hello",name,", you are ",age,"years old")
# Out:
# Hello  , you are   years old

# %%
# q3
 
string = input("enter the string : ")

reverse = " "
for char in string:
    reverse = char +reverse
print("reverse : ",reverse)

print("total number of the characters :",len(string))
# Out:
# reverse :
# total number of the characters : 0

# %%
# q4.

set1 = {1,2,3,4,2,6,7,9,7,3}

print(type(set1))

print("set1: ",set1)

set1.add(20)
print("add 20 in set1: ",set1)

set1.remove(2)
print("remove 2 in set1 :",set1)
# Out:
# <class 'set'>
# set1:  {1, 2, 3, 4, 6, 7, 9}
# add 20 in set1:  {1, 2, 3, 4, 20, 6, 7, 9}
# remove 2 in set1 : {1, 3, 4, 20, 6, 7, 9}

# %%
# Q5.

tuple1 = (2,4,6,8,8,10,12)

print(type(tuple1))

print(tuple1)

print(max(tuple1))
print(min(tuple1))

countnum = 8
print("count of ",countnum , " : ",tuple1.count(countnum))

numindex = 10

print("find the indexing of the number : ", numindex," : ", tuple1.index(numindex))
# Out:
# <class 'tuple'>
# (2, 4, 6, 8, 8, 10, 12)
# 12
# 2
# count of  8  :  2
# find the indexing of the number :  10  :  5
